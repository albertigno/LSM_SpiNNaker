# %%
"""
@author: albertigno
saucedo@imse-cnm.csic.es

"""

from DatasetLoader import *
import torch, time, os
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# check the type of device to be used
print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print (device)

# this is where our SRNN model is defined
from srnn_model import*
# Out:
# True
# cuda:0

# %% [markdown]
# ## Global parameters

# %%
# parameters
batch_size = 200
learning_rate = 1e-4
time_window = 25 
num_hidden = 512

# %% [markdown]
# ## Loading train and test set

# %%
# load dataset
train_path = r'./../../datasets/nmnist/nmnist_train.mat'
test_path = r'./../../datasets/nmnist/nmnist_test.mat'
print("loading test set...")
test_set = DatasetLoader(test_path, win=time_window, device='cpu')
test_loader = torch.utils.data.DataLoader(dataset=test_set,
                                          batch_size=batch_size,
                                          shuffle=False, drop_last=True)

print("loading training set...")
train_set = DatasetLoader(train_path, win=time_window, device=device)
train_loader = torch.utils.data.DataLoader(dataset=train_set,
                                           batch_size=batch_size,
                                           shuffle=True, drop_last=True)
# Out:
# loading test set...
# num sample: 10000
# torch.Size([10000, 25, 2312]) torch.Size([10000, 10])
# loading training set...
# num sample: 60000
# torch.Size([60000, 25, 2312]) torch.Size([60000, 10])

# %% [markdown]
# ## Instantiation of the LSM

# %%
# instantiate the LSM
snn = RSNN_Model(num_hidden, time_window, batch_size, device)
snn.freeze_parameters()
snn.to(device)
modelname = 'nmnist_rnn_lsm_{}.t7'.format(num_hidden)
print(modelname)
# Out:
# torch.Size([512, 2312])
# Frozen
# torch.Size([512, 512])
# Frozen
# torch.Size([10, 512])
# nmnist_rnn_lsm_512.t7

# %% [markdown]
# ## Training configuration

# %%
# Training configuration
num_epochs = 10
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(snn.parameters(), lr=learning_rate)
act_fun = ActFun.apply

# %% [markdown]
# ## Weight visualization

# %%
q = snn.plot_weights('hh', 'matrix', crop_size=30)

# %%
q = snn.plot_weights('hh', 'histogram')

# %% [markdown]
# ## Training Loop

# %%
# training loop
taus_m = []
max_acc = 0
for epoch in range(num_epochs):
    print('Epoch [%d/%d]'  % (epoch + 1, num_epochs))
    start_time = time.time()
    snn.train_step(train_loader, optimizer=optimizer, criterion=nn.MSELoss())
    t =  time.time() - start_time
    print('Time elasped:', t)
    
    # adjust learning rate
    optimizer = snn.lr_scheduler(optimizer, lr_decay_epoch=1)
    
    # evaluate every 2 epochs
    if (epoch + 1) % 2 == 0:
        snn.test(test_loader, criterion=nn.MSELoss())
        if snn.acc[-1][1]>max_acc:
            print('Saving max acc model')
            snn.save_model(modelname)
            max_acc = snn.acc[-1][1]
                
with open('training_log', 'a') as logs:
    logs.write("\nFinished training {} epochs for {}, batch_size {}, time_per_epoch {} s".format(num_epochs, modelname, batch_size, t))
# Out:
# Epoch [1/10]
# Step [100/300], Loss: 8.85300
# Step [200/300], Loss: 7.51985
# Step [300/300], Loss: 6.74164
# Time elasped: 10.259764432907104
# Epoch [2/10]
# Step [100/300], Loss: 6.21823
# Step [200/300], Loss: 5.84749
# Step [300/300], Loss: 5.56395
# Time elasped: 9.262975692749023
# Test Accuracy of the model on the test samples: 78.660
# Saving max acc model
# Epoch [3/10]
# Step [100/300], Loss: 5.36374
# Step [200/300], Loss: 5.16359
# Step [300/300], Loss: 5.05847
# Time elasped: 9.183351755142212
# Epoch [4/10]
# Step [100/300], Loss: 4.90159
# Step [200/300], Loss: 4.80900
# Step [300/300], Loss: 4.75180
# Time elasped: 9.292257308959961
# Test Accuracy of the model on the test samples: 82.250
# Saving max acc model
# Epoch [5/10]
# Step [100/300], Loss: 4.66619
# Step [200/300], Loss: 4.56302
# Step [300/300], Loss: 4.50444
# Time elasped: 9.161870956420898
# Epoch [6/10]
# Step [100/300], Loss: 4.46054
# Step [200/300], Loss: 4.39755
# Step [300/300], Loss: 4.36764
# Time elasped: 9.266843318939209
# Test Accuracy of the model on the test samples: 83.220
# Saving max acc model
# Epoch [7/10]
# Step [100/300], Loss: 4.31522
# Step [200/300], Loss: 4.29214
# Step [300/300], Loss: 4.22708
# Time elasped: 9.304093599319458
# Epoch [8/10]
# Step [100/300], Loss: 4.20066
# Step [200/300], Loss: 4.19022
# Step [300/300], Loss: 4.14542
# Time elasped: 9.216346740722656
# Test Accuracy of the model on the test samples: 84.340
# Saving max acc model
# Epoch [9/10]
# Step [100/300], Loss: 4.12176
# Step [200/300], Loss: 4.10253
# Step [300/300], Loss: 4.06812
# Time elasped: 9.25684404373169
# Epoch [10/10]
# Step [100/300], Loss: 4.06528
# Step [200/300], Loss: 4.02828
# Step [300/300], Loss: 4.00370
# Time elasped: 9.126317024230957
# Test Accuracy of the model on the test samples: 85.070
# Saving max acc model

# %% [markdown]
# ## Post-training weight visualization

# %%
q2 = snn.plot_weights('hh', 'matrix', crop_size=30)

# %% [markdown]
# ## Visualizing training and test loss

# %%
snn.load_model(modelname, batch_size=batch_size, device=device)
p = snn.plot_loss()

# %% [markdown]
# ## Saving the weights to numpy

# %%
snn.save_to_numpy(modelname[:-3])

# %% [markdown]
# ## Quantize weights

# %%
snn_q = RSNN_Model()
snn_q.load_model(modelname, batch_size=batch_size, device=device)
snn_q.quantize_weights(bits = 2)

# %% [markdown]
# ## Visualize weight quantization

# %%
q3 = snn_q.plot_weights('hh', 'matrix', crop_size=30)

# %%
q3 = snn_q.plot_weights('hh', 'histogram')

# %% [markdown]
# ## Evaluate performance of quantized LSM

# %%
print('base: ')
snn.test(test_loader, criterion=nn.MSELoss())
print('quantized: ')
snn_q.test(test_loader, criterion=nn.MSELoss())
# Out:
# base:
# Test Accuracy of the model on the test samples: 85.070
# quantized:
# Test Accuracy of the model on the test samples: 84.210

# %% [markdown]
# ## Saving the quantized weights to numpy

# %%
snn_q.save_to_numpy(modelname[:-3]+'_q2')
