# %%
from rsnn_spinn import *
import spynnaker8 as sim
# Out:
# /Users/alberto/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Detected PyNN version 0.9.5 and Neo version 0.6.1

# %% [markdown]
# ## Instantiating the custom LSM SpiNNaker simulator

# %%
s1 = RSNN_SPyNN(sim, timestep =1.0, modelname='rnn_lsm_512/', num_to_test= 20, tsf=5.0, npc=10)    
s1.run()
# Out:
# 2022-05-17 10:50:33 INFO: Read cfg files: /Users/alberto/anaconda3/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /Users/alberto/anaconda3/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg, /Users/alberto/.spynnaker.cfg
# 2022-05-17 10:50:33 INFO: Will search these locations for binaries: /Users/alberto/anaconda3/lib/python3.6/site-packages/spinn_front_end_common/common_model_binaries : /Users/alberto/anaconda3/lib/python3.6/site-packages/spynnaker/pyNN/model_binaries
# 2022-05-17 10:50:33 WARNING: /Users/alberto/reports has 26 old reports that have not been closed
# 2022-05-17 10:50:33 WARNING: /Users/alberto/application_generated_data_files has 23 old reports that have not been closed
# 2022-05-17 10:50:33 INFO: Setting time scale factor to 5.
# 2022-05-17 10:50:33 INFO: Setting machine time step to 1000 micro-seconds.
# ...

# %%
s1.plot_save()
s1.sim.end()
# Out:
# Getting spikes for AbstractPopulationVertex_2
# |0%                          50%                         100%|
# ...
# plotting....
# 2022-05-17 10:51:36 WARNING: No SDP packets were received by SpikeSourceArrayVertex_1:0:2311.  If you expected packets to be injected, this could indicate an error
# 2022-05-17 10:51:36 WARNING: No multicast packets were sent by SpikeSourceArrayVertex_1:0:2311.  If you expected packets to be sent this could indicate an error

# %%
s2 = RSNN_SPyNN(sim, timestep =1.0, modelname='rnn_lsm_512_q2/', num_to_test= 20, tsf=5.0, npc=10)    
s2.run()
# Out:
# 2022-05-17 10:52:03 INFO: Resetting
# 2022-05-17 10:52:03 INFO: Read cfg files: /Users/alberto/anaconda3/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /Users/alberto/anaconda3/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg, /Users/alberto/.spynnaker.cfg
# 2022-05-17 10:52:03 INFO: Will search these locations for binaries: /Users/alberto/anaconda3/lib/python3.6/site-packages/spinn_front_end_common/common_model_binaries : /Users/alberto/anaconda3/lib/python3.6/site-packages/spynnaker/pyNN/model_binaries
# 2022-05-17 10:52:03 WARNING: /Users/alberto/reports has 26 old reports that have not been closed
# 2022-05-17 10:52:03 WARNING: /Users/alberto/application_generated_data_files has 24 old reports that have not been closed
# 2022-05-17 10:52:03 INFO: Setting time scale factor to 5.
# 2022-05-17 10:52:03 INFO: Setting machine time step to 1000 micro-seconds.
# ...

# %%
s2.plot_save()
s2.sim.end()
# Out:
# Getting spikes for AbstractPopulationVertex_2
# |0%                          50%                         100%|
# ...
# plotting....
# 2022-05-17 10:53:04 WARNING: No SDP packets were received by SpikeSourceArrayVertex_1:0:2311.  If you expected packets to be injected, this could indicate an error
# 2022-05-17 10:53:04 WARNING: No multicast packets were sent by SpikeSourceArrayVertex_1:0:2311.  If you expected packets to be sent this could indicate an error

# %%
s3 = RSNN_SPyNN(sim, timestep =1.0, modelname='rnn_lsm_512/', num_to_test= 1000, tsf=5.0, npc=10)    
s3.run()
s3.sim.end()
# Out:
# 2022-05-17 11:02:32 INFO: Read cfg files: /Users/alberto/anaconda3/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /Users/alberto/anaconda3/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg, /Users/alberto/.spynnaker.cfg
# 2022-05-17 11:02:32 INFO: Will search these locations for binaries: /Users/alberto/anaconda3/lib/python3.6/site-packages/spinn_front_end_common/common_model_binaries : /Users/alberto/anaconda3/lib/python3.6/site-packages/spynnaker/pyNN/model_binaries
# 2022-05-17 11:02:32 WARNING: /Users/alberto/reports has 26 old reports that have not been closed
# 2022-05-17 11:02:32 WARNING: /Users/alberto/application_generated_data_files has 25 old reports that have not been closed
# 2022-05-17 11:02:32 INFO: Setting time scale factor to 5.
# 2022-05-17 11:02:32 INFO: Setting machine time step to 1000 micro-seconds.
# ...

# %%
s4 = RSNN_SPyNN(sim, timestep =1.0, modelname='rnn_lsm_512_q2/', num_to_test= 1000, tsf=5.0, npc=10)    
s4.run()
s4.sim.end()
# Out:
# 2022-05-17 11:08:51 INFO: Read cfg files: /Users/alberto/anaconda3/lib/python3.6/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /Users/alberto/anaconda3/lib/python3.6/site-packages/spynnaker/pyNN/spynnaker.cfg, /Users/alberto/.spynnaker.cfg
# 2022-05-17 11:08:51 INFO: Will search these locations for binaries: /Users/alberto/anaconda3/lib/python3.6/site-packages/spinn_front_end_common/common_model_binaries : /Users/alberto/anaconda3/lib/python3.6/site-packages/spynnaker/pyNN/model_binaries
# 2022-05-17 11:08:51 WARNING: /Users/alberto/reports has 26 old reports that have not been closed
# 2022-05-17 11:08:51 WARNING: /Users/alberto/application_generated_data_files has 26 old reports that have not been closed
# 2022-05-17 11:08:51 INFO: Setting time scale factor to 5.
# 2022-05-17 11:08:51 INFO: Setting machine time step to 1000 micro-seconds.
# ...
