# %%
from rsnn_spinn import *
import spynnaker8 as sim

# %% [markdown]
# ## Instantiating the custom LSM SpiNNaker simulator

# %%
s1 = RSNN_SPyNN(sim, timestep =1.0, modelname='rnn_lsm_512/', num_to_test= 20, tsf=5.0, npc=10)    
s1.run()
# Out:
# 2022-06-06 10:22:36 INFO: Read cfg files: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/bbpnrsoa/.spynnaker.cfg
# 2022-06-06 10:22:36 INFO: Will search these locations for binaries: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/common_model_binaries : /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/model_binaries
# 2022-06-06 10:22:36 INFO: Setting time scale factor to 5.
# 2022-06-06 10:22:36 INFO: Setting machine time step to 1000 micro-seconds.
# 2022-06-06 10:22:36 WARNING: SpikeSourceArray SpikeSourceArrayVertex_5 has spike_times that are lower than the current time 0.0 For example 2.0 - these will be ignored.
# ['/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg', '/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg', '/home/bbpnrsoa/.spynnaker.cfg']
# 2022-06-06 10:22:40 INFO: Starting execution process
# 2022-06-06 10:22:40 INFO: Simulating for 1000 1.0ms timesteps using a hardware timestep of 5000us
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:22:41 INFO: Time 0:00:00.010861 taken by SpynnakerSplitterSelector
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:22:41 INFO: Time 0:00:00.010269 taken by DelaySupportAdder
# 2022-06-06 10:22:43 INFO: Time 0:00:02.931088 taken by SpallocMaxMachineGenerator
# Preallocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:22:53 INFO: Time 0:00:09.498373 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  2022-06-06 10:22:58 WARNING: Combination of send_buffer_times [] and slice Slice(lo_atom=0, hi_atom=2311, n_atoms=2312) results in a core with a ReverseIPTagMulticastSourceMachineVertex which does not spike
# ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:03 INFO: Time 0:00:10.358119 taken by SpYNNakerSplitterPartitioner
# Created spalloc job 6456012
# 2022-06-06 10:23:03 INFO: Created spalloc job 6456012
# Waiting for board power commands to complete.
# 2022-06-06 10:23:03 INFO: Waiting for board power commands to complete.
# 2022-06-06 10:23:08 INFO: Time 0:00:05.051273 taken by SpallocAllocator
# 2022-06-06 10:23:08 INFO: Creating transceiver for 10.11.234.57
# 2022-06-06 10:23:08 INFO: Working out if machine is booted
# 2022-06-06 10:23:12 INFO: Attempting to boot machine
# 2022-06-06 10:23:18 INFO: Found board with version [Version: SC&MP 3.4.1 at SpiNNaker:0:0:0 (built Thu Feb 11 15:36:44 2021)]
# 2022-06-06 10:23:18 INFO: Machine communication successful
# 2022-06-06 10:23:18 INFO: Detected a machine on IP address 10.11.234.57 which has 837 cores and 114.0 links
# 2022-06-06 10:23:18 INFO: Time 0:00:09.935457 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:18 INFO: Time 0:00:00.011781 taken by PartitionerReport
# 2022-06-06 10:23:18 INFO: Time 0:00:00.000374 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:18 INFO: Time 0:00:00.030893 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:18 INFO: Time 0:00:00.030580 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.021575 taken by BoardChipReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.042800 taken by EdgeToNKeysMapper
# 2022-06-06 10:23:19 INFO: The time scale factor could be reduced to 3.7471875
# 2022-06-06 10:23:19 INFO: Time 0:00:00.001178 taken by LocalTDMABuilder
# Placing graph vertices via spreading over an entire machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.025422 taken by SpreaderPlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  =======================================2022-06-06 10:23:19 INFO: Time 0:00:00.047974 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.010215 taken by SystemMulticastRoutingGenerator
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.010281 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.067110 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:23:19 INFO: Time 0:00:00.424655 taken by NerRouteTrafficAware
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.053910 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.008417 taken by TagReport
# Getting constraints for machine graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.045818 taken by ProcessPartitionConstraints
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.019708 taken by ZonedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.024877 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.043104 taken by BasicRoutingTableGenerator
# 2022-06-06 10:23:19 INFO: Time 0:00:00.010673 taken by RouterCollisionPotentialReport
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.051443 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:19 INFO: Time 0:00:00.048766 taken by BufferManagerCreator
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:20 INFO: Time 0:00:00.044117 taken by SDRAMOutgoingPartitionAllocator
# Generating data specifications
# |0%                          50%                         100%|
#  ===========================/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/models/neural_projections/connectors/from_list_connector.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   split_indices = numpy.array(numpy.split(
# =================================
# 2022-06-06 10:23:32 INFO: Time 0:00:12.874039 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:33 INFO: Time 0:00:00.141710 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:33 INFO: Time 0:00:00.051667 taken by GraphBinaryGatherer
# Running pair routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:23:36 INFO: Time 0:00:03.538060 taken by PairOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:36 INFO: Time 0:00:00.050737 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:36 INFO: Time 0:00:00.048098 taken by LoadFixedRoutes
# Executing data specifications and loading data for system vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:38 INFO: Time 0:00:01.501798 taken by HostExecuteSystemDataSpecification
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:44 INFO: Time 0:00:05.756265 taken by LoadSystemExecutableImages
# 2022-06-06 10:23:44 INFO: Time 0:00:00.001854 taken by TagsFromMachineReport
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:23:44 INFO: Time 0:00:00.034670 taken by TagsLoader
# Executing data specifications and loading data for application vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:36 INFO: Time 0:02:52.160235 taken by HostExecuteApplicationDataSpecification
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2022-06-06 10:26:40 INFO: Time 0:00:03.905790 taken by SynapseExpander
# Running bitfield generation on chip
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2022-06-06 10:26:43 INFO: Time 0:00:03.412911 taken by OnChipBitFieldGenerator
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:43 INFO: Time 0:00:00.030601 taken by FinishConnectionHolders
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:44 INFO: Time 0:00:00.695946 taken by ReadRoutingTablesFromMachine
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:44 INFO: Time 0:00:00.059035 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:44 INFO: Time 0:00:00.028840 taken by comparisonOfRoutingTablesReport
# Generating Routing summary report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:44 INFO: Time 0:00:00.029403 taken by CompressedRouterSummaryReport
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:44 INFO: Time 0:00:00.057154 taken by RoutingTableFromMachineReport
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:44 INFO: Time 0:00:00.042630 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:51 INFO: Time 0:00:06.813502 taken by LoadApplicationExecutableImages
# 2022-06-06 10:26:51 INFO: Running for 1 steps for a total of 1000.0ms
# 2022-06-06 10:26:51 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:51 INFO: Time 0:00:00.087991 taken by SdramUsageReportPerChip
# 2022-06-06 10:26:51 INFO: creating live event connection database in /home/bbpnrsoa/LSM sPyNNaker/reports/2022-06-06-10-22-36-469488/run_1/input_output_database.db
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:51 INFO: Time 0:00:00.218752 taken by DatabaseInterface
# 2022-06-06 10:26:51 INFO: ** Notifying external sources that the database is ready for reading **
# 2022-06-06 10:26:51 INFO: Time 0:00:00.001275 taken by CreateNotificationProtocol
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:51 INFO: Time 0:00:00.103651 taken by GraphProvenanceGatherer
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:51 INFO: Time 0:00:00.065028 taken by ChipRuntimeUpdater
# 2022-06-06 10:26:51 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:52 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2022-06-06 10:26:52 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2022-06-06 10:26:52 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2022-06-06 10:26:52 INFO: Application started; waiting 5.1s for it to stop
# 2022-06-06 10:26:57 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2022-06-06 10:26:57 INFO: Time 0:00:05.516195 taken by ApplicationRunner
# Extracting IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:57 INFO: Time 0:00:00.075555 taken by ChipIOBufExtractor
# clearing IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:57 INFO: Time 0:00:00.044059 taken by ChipIOBufClearer
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:26:58 INFO: Time 0:00:01.330808 taken by BufferExtractor
# 2022-06-06 10:26:58 INFO: Time 0:00:00.000146 taken by FinaliseTimingData
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:58 INFO: Time 0:00:00.123300 taken by PlacementsProvenanceGatherer
# 2022-06-06 10:26:58 INFO: Time 0:00:00.001580 taken by RedundantPacketCountReport
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:59 INFO: Time 0:00:00.073495 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:26:59 INFO: Time 0:00:00.106636 taken by ProfileDataGatherer
# Getting spikes for AbstractPopulationVertex_3
# |0%                          50%                         100%|
#  ============================================================
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
# [7 2 1 0 4 1 4 9 4 9 0 6 9 0 1 3 9 7 6 4]
# accuracy: 85.0%

# %% [markdown]
# ## Plot activity

# %%
s1.plot_save()
s1.sim.end()
# Out:
# Getting spikes for AbstractPopulationVertex_2
# |0%                          50%                         100%|
#  ============================================================
# plotting....
# 2022-05-17 10:51:36 WARNING: No SDP packets were received by SpikeSourceArrayVertex_1:0:2311.  If you expected packets to be injected, this could indicate an error
# 2022-05-17 10:51:36 WARNING: No multicast packets were sent by SpikeSourceArrayVertex_1:0:2311.  If you expected packets to be sent this could indicate an error

# %% [markdown]
# ## Test the quantized model

# %%
s2 = RSNN_SPyNN(sim, timestep =1.0, modelname='rnn_lsm_512_q2/', num_to_test= 20, tsf=5.0, npc=10)    
s2.run()
s2.sim.end()
# Out:
# 2022-06-06 10:28:28 INFO: Read cfg files: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/bbpnrsoa/.spynnaker.cfg
# 2022-06-06 10:28:28 INFO: Will search these locations for binaries: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/common_model_binaries : /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/model_binaries
# 2022-06-06 10:28:28 INFO: Setting time scale factor to 5.
# 2022-06-06 10:28:28 INFO: Setting machine time step to 1000 micro-seconds.
# 2022-06-06 10:28:28 WARNING: SpikeSourceArray SpikeSourceArrayVertex_5 has spike_times that are lower than the current time 0.0 For example 2.0 - these will be ignored.
# ['/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg', '/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg', '/home/bbpnrsoa/.spynnaker.cfg']
# 2022-06-06 10:28:32 INFO: Starting execution process
# 2022-06-06 10:28:32 INFO: Simulating for 1000 1.0ms timesteps using a hardware timestep of 5000us
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:28:32 INFO: Time 0:00:00.010497 taken by SpynnakerSplitterSelector
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:28:32 INFO: Time 0:00:00.011584 taken by DelaySupportAdder
# 2022-06-06 10:28:35 INFO: Time 0:00:02.848704 taken by SpallocMaxMachineGenerator
# Preallocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:28:44 INFO: Time 0:00:09.185034 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  2022-06-06 10:28:50 WARNING: Combination of send_buffer_times [] and slice Slice(lo_atom=0, hi_atom=2311, n_atoms=2312) results in a core with a ReverseIPTagMulticastSourceMachineVertex which does not spike
# ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:28:54 INFO: Time 0:00:09.488362 taken by SpYNNakerSplitterPartitioner
# Created spalloc job 6456013
# 2022-06-06 10:28:54 INFO: Created spalloc job 6456013
# Waiting for board power commands to complete.
# 2022-06-06 10:28:54 INFO: Waiting for board power commands to complete.
# 2022-06-06 10:28:59 INFO: Time 0:00:05.050335 taken by SpallocAllocator
# 2022-06-06 10:28:59 INFO: Creating transceiver for 10.11.234.57
# 2022-06-06 10:28:59 INFO: Working out if machine is booted
# 2022-06-06 10:29:03 INFO: Attempting to boot machine
# 2022-06-06 10:29:09 INFO: Found board with version [Version: SC&MP 3.4.1 at SpiNNaker:0:0:0 (built Thu Feb 11 15:36:44 2021)]
# 2022-06-06 10:29:09 INFO: Machine communication successful
# 2022-06-06 10:29:09 INFO: Detected a machine on IP address 10.11.234.57 which has 837 cores and 114.0 links
# 2022-06-06 10:29:09 INFO: Time 0:00:09.938861 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.018381 taken by PartitionerReport
# 2022-06-06 10:29:09 INFO: Time 0:00:00.000243 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.051381 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.031879 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.006622 taken by BoardChipReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.059804 taken by EdgeToNKeysMapper
# 2022-06-06 10:29:09 INFO: The time scale factor could be reduced to 3.7471875
# 2022-06-06 10:29:09 INFO: Time 0:00:00.001160 taken by LocalTDMABuilder
# Placing graph vertices via spreading over an entire machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.026194 taken by SpreaderPlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  =======================================2022-06-06 10:29:09 INFO: Time 0:00:00.040449 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.010544 taken by SystemMulticastRoutingGenerator
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.007824 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.058455 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:29:09 INFO: Time 0:00:00.125791 taken by NerRouteTrafficAware
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.053768 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.009279 taken by TagReport
# Getting constraints for machine graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.044841 taken by ProcessPartitionConstraints
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:09 INFO: Time 0:00:00.018141 taken by ZonedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:10 INFO: Time 0:00:00.027271 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:10 INFO: Time 0:00:00.043743 taken by BasicRoutingTableGenerator
# 2022-06-06 10:29:10 INFO: Time 0:00:00.010970 taken by RouterCollisionPotentialReport
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:10 INFO: Time 0:00:00.045571 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:10 INFO: Time 0:00:00.044463 taken by BufferManagerCreator
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:10 INFO: Time 0:00:00.043173 taken by SDRAMOutgoingPartitionAllocator
# Generating data specifications
# |0%                          50%                         100%|
#  ===========================/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/models/neural_projections/connectors/from_list_connector.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   split_indices = numpy.array(numpy.split(
# =================================
# 2022-06-06 10:29:23 INFO: Time 0:00:13.070254 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:23 INFO: Time 0:00:00.130286 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:23 INFO: Time 0:00:00.075072 taken by GraphBinaryGatherer
# Running pair routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:29:27 INFO: Time 0:00:03.677732 taken by PairOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:27 INFO: Time 0:00:00.061795 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:27 INFO: Time 0:00:00.061057 taken by LoadFixedRoutes
# Executing data specifications and loading data for system vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:28 INFO: Time 0:00:01.381692 taken by HostExecuteSystemDataSpecification
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:34 INFO: Time 0:00:05.756865 taken by LoadSystemExecutableImages
# 2022-06-06 10:29:34 INFO: Time 0:00:00.001830 taken by TagsFromMachineReport
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:29:34 INFO: Time 0:00:00.028121 taken by TagsLoader
# Executing data specifications and loading data for application vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:32 INFO: Time 0:01:58.303697 taken by HostExecuteApplicationDataSpecification
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2022-06-06 10:31:36 INFO: Time 0:00:03.930564 taken by SynapseExpander
# Running bitfield generation on chip
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2022-06-06 10:31:40 INFO: Time 0:00:03.416984 taken by OnChipBitFieldGenerator
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:40 INFO: Time 0:00:00.053976 taken by FinishConnectionHolders
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:40 INFO: Time 0:00:00.686827 taken by ReadRoutingTablesFromMachine
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:40 INFO: Time 0:00:00.048852 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:40 INFO: Time 0:00:00.029131 taken by comparisonOfRoutingTablesReport
# Generating Routing summary report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:41 INFO: Time 0:00:00.025692 taken by CompressedRouterSummaryReport
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:41 INFO: Time 0:00:00.053640 taken by RoutingTableFromMachineReport
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:41 INFO: Time 0:00:00.042575 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:47 INFO: Time 0:00:06.813343 taken by LoadApplicationExecutableImages
# 2022-06-06 10:31:47 INFO: Running for 1 steps for a total of 1000.0ms
# 2022-06-06 10:31:47 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:48 INFO: Time 0:00:00.075414 taken by SdramUsageReportPerChip
# 2022-06-06 10:31:48 INFO: creating live event connection database in /home/bbpnrsoa/LSM sPyNNaker/reports/2022-06-06-10-28-28-570013/run_1/input_output_database.db
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:48 INFO: Time 0:00:00.197044 taken by DatabaseInterface
# 2022-06-06 10:31:48 INFO: ** Notifying external sources that the database is ready for reading **
# 2022-06-06 10:31:48 INFO: Time 0:00:00.001142 taken by CreateNotificationProtocol
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:48 INFO: Time 0:00:00.103192 taken by GraphProvenanceGatherer
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:48 INFO: Time 0:00:00.065004 taken by ChipRuntimeUpdater
# 2022-06-06 10:31:48 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:48 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2022-06-06 10:31:48 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2022-06-06 10:31:48 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2022-06-06 10:31:48 INFO: Application started; waiting 5.1s for it to stop
# 2022-06-06 10:31:53 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2022-06-06 10:31:53 INFO: Time 0:00:05.500660 taken by ApplicationRunner
# Extracting IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:53 INFO: Time 0:00:00.058306 taken by ChipIOBufExtractor
# clearing IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:54 INFO: Time 0:00:00.036293 taken by ChipIOBufClearer
# Extracting buffers from the last run
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:31:55 INFO: Time 0:00:01.211319 taken by BufferExtractor
# 2022-06-06 10:31:55 INFO: Time 0:00:00.000155 taken by FinaliseTimingData
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:55 INFO: Time 0:00:00.110781 taken by PlacementsProvenanceGatherer
# 2022-06-06 10:31:55 INFO: Time 0:00:00.001607 taken by RedundantPacketCountReport
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:55 INFO: Time 0:00:00.071478 taken by RouterProvenanceGatherer
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:31:55 INFO: Time 0:00:00.097060 taken by ProfileDataGatherer
# Getting spikes for AbstractPopulationVertex_3
# |0%                          50%                         100%|
#  ============================================================
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
# [7 2 1 0 4 1 4 9 4 9 0 6 9 0 1 3 9 7 6 4]
# accuracy: 85.0%

# %% [markdown]
# ## Test 1000 samples, base

# %%
s3 = RSNN_SPyNN(sim, timestep =1.0, modelname='rnn_lsm_512/', num_to_test= 1000, tsf=5.0, npc=10)    
s3.run()
s3.sim.end()
# Out:
# 2022-06-06 10:32:20 INFO: Read cfg files: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/bbpnrsoa/.spynnaker.cfg
# 2022-06-06 10:32:20 INFO: Will search these locations for binaries: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/common_model_binaries : /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/model_binaries
# 2022-06-06 10:32:20 INFO: Setting time scale factor to 5.
# 2022-06-06 10:32:20 INFO: Setting machine time step to 1000 micro-seconds.
# ['/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg', '/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg', '/home/bbpnrsoa/.spynnaker.cfg']
# 2022-06-06 10:32:20 WARNING: SpikeSourceArray SpikeSourceArrayVertex_5 has spike_times that are lower than the current time 0.0 For example 4014.0 - these will be ignored.
# 2022-06-06 10:32:25 INFO: Starting execution process
# 2022-06-06 10:32:25 INFO: Simulating for 50000 1.0ms timesteps using a hardware timestep of 5000us
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:32:25 INFO: Time 0:00:00.009642 taken by SpynnakerSplitterSelector
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:32:25 INFO: Time 0:00:00.009954 taken by DelaySupportAdder
# 2022-06-06 10:32:28 INFO: Time 0:00:02.859528 taken by SpallocMaxMachineGenerator
# Preallocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:32:37 INFO: Time 0:00:08.834019 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  2022-06-06 10:32:42 WARNING: Combination of send_buffer_times [] and slice Slice(lo_atom=0, hi_atom=2311, n_atoms=2312) results in a core with a ReverseIPTagMulticastSourceMachineVertex which does not spike
# ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:32:47 INFO: Time 0:00:10.318200 taken by SpYNNakerSplitterPartitioner
# Created spalloc job 6456014
# 2022-06-06 10:32:47 INFO: Created spalloc job 6456014
# Waiting for board power commands to complete.
# 2022-06-06 10:32:47 INFO: Waiting for board power commands to complete.
# 2022-06-06 10:32:52 INFO: Time 0:00:05.049693 taken by SpallocAllocator
# 2022-06-06 10:32:52 INFO: Creating transceiver for 10.11.213.161
# 2022-06-06 10:32:52 INFO: Working out if machine is booted
# 2022-06-06 10:32:56 INFO: Attempting to boot machine
# 2022-06-06 10:33:02 INFO: Found board with version [Version: SC&MP 3.4.1 at SpiNNaker:0:0:0 (built Thu Feb 11 15:36:44 2021)]
# 2022-06-06 10:33:02 INFO: Machine communication successful
# 2022-06-06 10:33:02 INFO: Detected a machine on IP address 10.11.213.161 which has 835 cores and 114.0 links
# 2022-06-06 10:33:02 INFO: Time 0:00:09.935830 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:02 INFO: Time 0:00:00.016555 taken by PartitionerReport
# 2022-06-06 10:33:02 INFO: Time 0:00:00.000273 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:02 INFO: Time 0:00:00.055577 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:02 INFO: Time 0:00:00.035088 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:02 INFO: Time 0:00:00.004405 taken by BoardChipReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:02 INFO: Time 0:00:00.064756 taken by EdgeToNKeysMapper
# 2022-06-06 10:33:02 INFO: The time scale factor could be reduced to 3.7471875
# 2022-06-06 10:33:02 INFO: Time 0:00:00.001175 taken by LocalTDMABuilder
# Placing graph vertices via spreading over an entire machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:02 INFO: Time 0:00:00.037415 taken by SpreaderPlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  =======================================2022-06-06 10:33:02 INFO: Time 0:00:00.045226 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:02 INFO: Time 0:00:00.007238 taken by SystemMulticastRoutingGenerator
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:02 INFO: Time 0:00:00.009400 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:02 INFO: Time 0:00:00.065877 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:33:02 INFO: Time 0:00:00.136712 taken by NerRouteTrafficAware
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:03 INFO: Time 0:00:00.064085 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:03 INFO: Time 0:00:00.006394 taken by TagReport
# Getting constraints for machine graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:03 INFO: Time 0:00:00.050473 taken by ProcessPartitionConstraints
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:03 INFO: Time 0:00:00.012289 taken by ZonedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:03 INFO: Time 0:00:00.027333 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:03 INFO: Time 0:00:00.040952 taken by BasicRoutingTableGenerator
# 2022-06-06 10:33:03 INFO: Time 0:00:00.032396 taken by RouterCollisionPotentialReport
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:03 INFO: Time 0:00:00.065380 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:03 INFO: Time 0:00:00.050172 taken by BufferManagerCreator
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:03 INFO: Time 0:00:00.047050 taken by SDRAMOutgoingPartitionAllocator
# Generating data specifications
# |0%                          50%                         100%|
#  ===========================/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/models/neural_projections/connectors/from_list_connector.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   split_indices = numpy.array(numpy.split(
# =================================
# 2022-06-06 10:33:17 INFO: Time 0:00:14.394908 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:19 INFO: Time 0:00:00.151904 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:19 INFO: Time 0:00:00.075444 taken by GraphBinaryGatherer
# Running pair routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:33:22 INFO: Time 0:00:03.519136 taken by PairOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:22 INFO: Time 0:00:00.056710 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:22 INFO: Time 0:00:00.051588 taken by LoadFixedRoutes
# Executing data specifications and loading data for system vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:24 INFO: Time 0:00:01.354835 taken by HostExecuteSystemDataSpecification
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:29 INFO: Time 0:00:05.758439 taken by LoadSystemExecutableImages
# 2022-06-06 10:33:29 INFO: Time 0:00:00.002050 taken by TagsFromMachineReport
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:33:29 INFO: Time 0:00:00.019177 taken by TagsLoader
# Executing data specifications and loading data for application vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:15 INFO: Time 0:02:45.803778 taken by HostExecuteApplicationDataSpecification
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2022-06-06 10:36:19 INFO: Time 0:00:03.902734 taken by SynapseExpander
# Running bitfield generation on chip
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2022-06-06 10:36:23 INFO: Time 0:00:03.426067 taken by OnChipBitFieldGenerator
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:23 INFO: Time 0:00:00.045197 taken by FinishConnectionHolders
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:23 INFO: Time 0:00:00.702403 taken by ReadRoutingTablesFromMachine
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:23 INFO: Time 0:00:00.046641 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:23 INFO: Time 0:00:00.029926 taken by comparisonOfRoutingTablesReport
# Generating Routing summary report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:23 INFO: Time 0:00:00.032363 taken by CompressedRouterSummaryReport
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:24 INFO: Time 0:00:00.044299 taken by RoutingTableFromMachineReport
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:24 INFO: Time 0:00:00.041428 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:30 INFO: Time 0:00:06.815318 taken by LoadApplicationExecutableImages
# 2022-06-06 10:36:30 INFO: Running for 1 steps for a total of 50000.0ms
# 2022-06-06 10:36:30 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:32 INFO: Time 0:00:00.114204 taken by SdramUsageReportPerChip
# 2022-06-06 10:36:32 INFO: creating live event connection database in /home/bbpnrsoa/LSM sPyNNaker/reports/2022-06-06-10-32-20-602752/run_1/input_output_database.db
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:32 INFO: Time 0:00:00.203056 taken by DatabaseInterface
# 2022-06-06 10:36:32 INFO: ** Notifying external sources that the database is ready for reading **
# 2022-06-06 10:36:32 INFO: Time 0:00:00.000833 taken by CreateNotificationProtocol
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:32 INFO: Time 0:00:00.101253 taken by GraphProvenanceGatherer
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:36:32 INFO: Time 0:00:00.064675 taken by ChipRuntimeUpdater
# 2022-06-06 10:36:32 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:37:00 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2022-06-06 10
#  3 2 3 9 1 6 4 0 3 5 5 8 6 3 0 6 7 6 6 3 2 7 8 1 1 2 5 6 4 9 6 6 3 3 3 9 8
#  9 1 1 0 9 1 4 4 5 4 0 6 2 2 3 1 5 1 2 0 8 8 1 2 6 7 7 6 2 3 3 0 2 2 2 0 6
#  7]
# accuracy: 81.2%

# %% [markdown]
# ## Test 1000 samples, quantized

# %%
s4 = RSNN_SPyNN(sim, timestep =1.0, modelname='rnn_lsm_512_q2/', num_to_test= 1000, tsf=5.0, npc=10)    
s4.run()
s4.sim.end()
# Out:
# 2022-06-06 10:41:25 INFO: Read cfg files: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/bbpnrsoa/.spynnaker.cfg
# 2022-06-06 10:41:25 INFO: Will search these locations for binaries: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/common_model_binaries : /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/model_binaries
# 2022-06-06 10:41:25 INFO: Setting time scale factor to 5.
# 2022-06-06 10:41:25 INFO: Setting machine time step to 1000 micro-seconds.
# ['/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg', '/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg', '/home/bbpnrsoa/.spynnaker.cfg']
# 2022-06-06 10:41:25 WARNING: SpikeSourceArray SpikeSourceArrayVertex_5 has spike_times that are lower than the current time 0.0 For example 4014.0 - these will be ignored.
# 2022-06-06 10:41:30 INFO: Starting execution process
# 2022-06-06 10:41:30 INFO: Simulating for 50000 1.0ms timesteps using a hardware timestep of 5000us
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:41:30 INFO: Time 0:00:00.015053 taken by SpynnakerSplitterSelector
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:41:30 INFO: Time 0:00:00.010465 taken by DelaySupportAdder
# 2022-06-06 10:41:33 INFO: Time 0:00:03.136064 taken by SpallocMaxMachineGenerator
# Preallocating resources for Extra Monitor support vertices
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:41:42 INFO: Time 0:00:09.248270 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# |0%                          50%                         100%|
#  2022-06-06 10:41:48 WARNING: Combination of send_buffer_times [] and slice Slice(lo_atom=0, hi_atom=2311, n_atoms=2312) results in a core with a ReverseIPTagMulticastSourceMachineVertex which does not spike
# ============================================================
# Partitioning graph edges
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:41:52 INFO: Time 0:00:09.594808 taken by SpYNNakerSplitterPartitioner
# Created spalloc job 6456017
# 2022-06-06 10:41:52 INFO: Created spalloc job 6456017
# Waiting for board power commands to complete.
# 2022-06-06 10:41:52 INFO: Waiting for board power commands to complete.
# 2022-06-06 10:41:57 INFO: Time 0:00:05.049816 taken by SpallocAllocator
# 2022-06-06 10:41:57 INFO: Creating transceiver for 10.11.213.161
# 2022-06-06 10:41:57 INFO: Working out if machine is booted
# 2022-06-06 10:42:01 INFO: Attempting to boot machine
# 2022-06-06 10:42:07 INFO: Found board with version [Version: SC&MP 3.4.1 at SpiNNaker:0:0:0 (built Thu Feb 11 15:36:44 2021)]
# 2022-06-06 10:42:07 INFO: Machine communication successful
# 2022-06-06 10:42:07 INFO: Detected a machine on IP address 10.11.213.161 which has 835 cores and 114.0 links
# 2022-06-06 10:42:07 INFO: Time 0:00:09.936305 taken by MachineGenerator
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.015712 taken by PartitionerReport
# 2022-06-06 10:42:07 INFO: Time 0:00:00.000241 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.062648 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.030737 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.007892 taken by BoardChipReport
# Getting number of keys required by each edge using application graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.045191 taken by EdgeToNKeysMapper
# 2022-06-06 10:42:07 INFO: The time scale factor could be reduced to 3.7471875
# 2022-06-06 10:42:07 INFO: Time 0:00:00.001280 taken by LocalTDMABuilder
# Placing graph vertices via spreading over an entire machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.035914 taken by SpreaderPlacer
# Inserting edges between vertices which require FR speed up functionality.
# |0%                          50%                         100%|
#  =======================================2022-06-06 10:42:07 INFO: Time 0:00:00.039765 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.010339 taken by SystemMulticastRoutingGenerator
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.008824 taken by FixedRouteRouter
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.054145 taken by PlacerReportWithApplicationGraph
# Routing
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:42:07 INFO: Time 0:00:00.143483 taken by NerRouteTrafficAware
# Discovering tags
# |0%                          50%                         100%|
#  ============================================================
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.066660 taken by BasicTagAllocator
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.008878 taken by TagReport
# Getting constraints for machine graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.047473 taken by ProcessPartitionConstraints
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:07 INFO: Time 0:00:00.018514 taken by ZonedRoutingInfoAllocator
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:08 INFO: Time 0:00:00.026944 taken by routingInfoReports
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:08 INFO: Time 0:00:00.045632 taken by BasicRoutingTableGenerator
# 2022-06-06 10:42:08 INFO: Time 0:00:00.011087 taken by RouterCollisionPotentialReport
# Finding executable start types
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:08 INFO: Time 0:00:00.044676 taken by LocateExecutableStartType
# Initialising buffers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:08 INFO: Time 0:00:00.049306 taken by BufferManagerCreator
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:08 INFO: Time 0:00:00.043919 taken by SDRAMOutgoingPartitionAllocator
# Generating data specifications
# |0%                          50%                         100%|
#  ===========================/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/models/neural_projections/connectors/from_list_connector.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   split_indices = numpy.array(numpy.split(
# =================================
# 2022-06-06 10:42:22 INFO: Time 0:00:13.834014 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:23 INFO: Time 0:00:00.137550 taken by RoutingSetup
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:23 INFO: Time 0:00:00.054311 taken by GraphBinaryGatherer
# Running pair routing table compression on chip
# |0%                          50%                         100%|
#  ============================================================
#
# 2022-06-06 10:42:27 INFO: Time 0:00:03.531685 taken by PairOnChipRouterCompression
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:27 INFO: Time 0:00:00.045650 taken by unCompressedRoutingTableReports
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:27 INFO: Time 0:00:00.043509 taken by LoadFixedRoutes
# Executing data specifications and loading data for system vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:28 INFO: Time 0:00:01.356269 taken by HostExecuteSystemDataSpecification
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:34 INFO: Time 0:00:05.755110 taken by LoadSystemExecutableImages
# 2022-06-06 10:42:34 INFO: Time 0:00:00.001915 taken by TagsFromMachineReport
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:42:34 INFO: Time 0:00:00.024253 taken by TagsLoader
# Executing data specifications and loading data for application vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:38 INFO: Time 0:02:04.713580 taken by HostExecuteApplicationDataSpecification
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2022-06-06 10:44:42 INFO: Time 0:00:03.918967 taken by SynapseExpander
# Running bitfield generation on chip
# |0%                          50%                         100%|
#  ============================================================
#
#
# 2022-06-06 10:44:46 INFO: Time 0:00:03.415653 taken by OnChipBitFieldGenerator
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:46 INFO: Time 0:00:00.026186 taken by FinishConnectionHolders
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:47 INFO: Time 0:00:00.714562 taken by ReadRoutingTablesFromMachine
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:47 INFO: Time 0:00:00.062653 taken by compressedRoutingTableReports
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:47 INFO: Time 0:00:00.029613 taken by comparisonOfRoutingTablesReport
# Generating Routing summary report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:47 INFO: Time 0:00:00.030158 taken by CompressedRouterSummaryReport
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:47 INFO: Time 0:00:00.049628 taken by RoutingTableFromMachineReport
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:47 INFO: Time 0:00:00.046769 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:54 INFO: Time 0:00:06.821122 taken by LoadApplicationExecutableImages
# 2022-06-06 10:44:54 INFO: Running for 1 steps for a total of 50000.0ms
# 2022-06-06 10:44:54 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:55 INFO: Time 0:00:00.137721 taken by SdramUsageReportPerChip
# 2022-06-06 10:44:55 INFO: creating live event connection database in /home/bbpnrsoa/LSM sPyNNaker/reports/2022-06-06-10-41-25-635758/run_1/input_output_database.db
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:55 INFO: Time 0:00:00.216328 taken by DatabaseInterface
# 2022-06-06 10:44:55 INFO: ** Notifying external sources that the database is ready for reading **
# 2022-06-06 10:44:55 INFO: Time 0:00:00.000958 taken by CreateNotificationProtocol
# Getting provenance data from machine graph
# |0%                          50%                         100%|
#  ============================================================
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:55 INFO: Time 0:00:00.129563 taken by GraphProvenanceGatherer
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:44:55 INFO: Time 0:00:00.076337 taken by ChipRuntimeUpdater
# 2022-06-06 10:44:55 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:45:23 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2022-06-06 10:45:23 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2022-06-06 10:45:23 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2022-06-06 10:45:23 INFO: Application started; waiting 250.1s for it to stop
# 2022-06-06 10:49:34 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2022-06-06 10:49:34 INFO: Time 0:04:38.264107 taken by ApplicationRunner
# Extracting IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10:49:34 INFO: Time 0:00:00.058989 taken by ChipIOBufExtractor
# clearing IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2022-06-06 10