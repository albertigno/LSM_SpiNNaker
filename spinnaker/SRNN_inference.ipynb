# %%
from rsnn_pynn import *
# %load_ext autoreload
# %autoreload 1
# %aimport rsnn_pynn

# %%
import pyNN.nest as sim
# Out:
# CSAConnector: libneurosim support not available in NEST.
# Falling back on PyNN's default CSAConnector.
# Please re-compile NEST using --with-libneurosim=PATH
# /Users/alberto/anaconda3/envs/pynn-nest/lib/python3.7/site-packages/pyNN/nest/__init__.py:53: UserWarning:Unable to install NEST extensions. Certain models may not be available.

# %%
s1 = RSNN_PyNN(sim, timestep =1.0, dataset='shd', modelname='rnn_256/', num_to_test= 100)
# Out:
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in

# %%
s1.run()
# Out:
# [10 11  7 10  3  5  0 10 18  5 16 14 12  8  0 16 10 16 17 13 19  9  7  4
#   6  9  0  0  9  9  6  2  3 12  8  8  7 10 12 10 14  8  6  0 11  8  7 17
#   5  7 13 11 18  6 11  6 15 17 14  0  1 18 17 13  0 18 13  5 14  1 10 13
#  14 14 10 11  4  3  7 17  8  7 14 14  7 16  3 14 15  5 19 10 16  8 19  0
#  19  1  6  1]
# [10 18  7 10  3  9  0 10 18  5 18  3 17  8 17 16  3 18  3 13  4 13  7  4
#   6 13  0  0  9  9  6  2 15 13  3  8  7 10 13 10 14  8  6 10 13  8  7 17
#   9  7 13 11 18  6 16  6 15 17 14  2  1 18 17 13  0 18 13  5 14 13 10  5
#  14 14  2 13  4 10  7 17  8  7  0  3  7  6  4 14 15 15  1 10  8  8  5 17
#  19  9  6  1]
# accuracy: 64.0%

# %%
s1.plot_save()
# Out:
# plotting....

# %%
s2 = RSNN_PyNN(sim, timestep =1.0, dataset='shd', modelname='rnn_256r/', num_to_test= 100)   
s2.run()
# Out:
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# [10 11  7 10  3  5  0 10 18  5 16 14 12  8  0 16 10 16 17 13 19  9  7  4
#   6  9  0  0  9  9  6  2  3 12  8  8  7 10 12 10 14  8  6  0 11  8  7 17
#   5  7 13 11 18  6 11  6 15 17 14  0  1 18 17 13  0 18 13  5 14  1 10 13
#  14 14 10 11  4  3  7 17  8  7 14 14  7 16  3 14 15  5 19 10 16  8 19  0
#  19  1  6  1]
# [ 0 11 12  0  3 18  0 14 18  5 16  0 12  8  0  6 10  6 17 13  4 13  7  0
#   6 13  0  0 11  5  6  2 15 12  8  8 12  0  5  4 14  8  6  0 13  8  7 17
#   9  7 13 11 18  6  8  6 15 17 14  0  5 18 17 13  0 18 13  5 14  1  0  5
#  14 14 15 11  4 10  7  0  8  7  0 17  2  6 10 10 10  5  9 10  6  8  1  0
#   1  1 16  1]
# accuracy: 60.0%

# %%
s2.plot_save()
# Out:
# plotting....

# %%
s2 = RSNN_PyNN(sim, timestep =1.0, dataset='mnist', modelname='rnn_32/', num_to_test= 20)
# Out:
# /Users/alberto/anaconda3/envs/pynn-nest/lib/python3.7/site-packages/nest/lib/hl_api_helper.py:127: UserWarning:
# ResetNetwork is deprecated and will be removed in NEST 3.0.
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in

# %%
s2.run()
# Out:
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 8 4]
# accuracy: 95.0%

# %%
s2 = RSNN_PyNN(sim, timestep =1.0, dataset='nmnist', modelname='rnn_256/', num_to_test= 20)
s2.run()
# Out:
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
# [7 2 1 0 4 1 8 9 5 9 0 6 9 0 1 5 9 7 3 4]
# accuracy: 95.0%

# %%
s2.plot_save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-51de56562c28> in <module>
# ----> 1 s2.plot_save()
#
# AttributeError: 'RSNN_PyNN' object has no attribute 'plot_save'

# %%
s4 = RSNN_PyNN(sim, timestep =1.0, dataset='nmnist', modelname='rnn_lsm_256/', num_to_test= 20)
s4.run()
# Out:
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# [7 2 1 0 4 1 4 9 5 9 0 6 9 0 1 5 9 7 3 4]
# [7 2 1 0 4 1 4 9 4 0 0 0 4 0 0 3 9 7 3 4]
# accuracy: 70.0%

# %%
s4.plot_save()
# Out:
# plotting....

# %%
s = RSNN_PyNN(sim, timestep =1.0, dataset='shd', modelname='rnn_32/', num_to_test= 100)    
s.run()
s.plot_save()
# Out:
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# NEST does not allow setting an initial value for g_ex
# NEST does not allow setting an initial value for g_in
# [10 11  7 10  3  5  0 10 18  5 16 14 12  8  0 16 10 16 17 13 19  9  7  4
#   6  9  0  0  9  9  6  2  3 12  8  8  7 10 12 10 14  8  6  0 11  8  7 17
#   5  7 13 11 18  6 11  6 15 17 14  0  1 18 17 13  0 18 13  5 14  1 10 13
#  14 14 10 11  4  3  7 17  8  7 14 14  7 16  3 14 15  5 19 10 16  8 19  0
#  19  1  6  1]
# [10  6 11 10  2  5 17  0 18  5  7  2  6  8  2  6  2 16 17 18  4  5  1  0
#   6 10 17  0  9  1  6 16 10 13  8  8  2  0  3  0 19  8  6  2 11  8  1 17
#   9  1 13 18 16  6 16  6 19 17  3  2  1 18 10 13  2 18  9 18  8  9  2  5
#   2 10  0 18  4 15  6  1  6  1  4 10  8  6  1  0 10  1  9 10  7  8  9  0
#   9  9 16 17]
# accuracy: 31.0%
# ...
